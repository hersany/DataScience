# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('store_sharing.csv')

# %%
df.head(2)
# Out:
#              timestamp  cnt   t1   t2   hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0  93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5  93.0         5.0           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0

# %%
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.

# %%
df.nunique()
# Out:
# timestamp       17414
# cnt              3781
# t1                 73
# t2                 82
# hum               143
# wind_speed        103
# weather_code        7
# is_holiday          2
# is_weekend          2
# season              4
# dtype: int64

# %%
pd.to_datetime(df['timestamp']).dt.date
# Out:
# 0        2015-01-04
# 1        2015-01-04
# 2        2015-01-04
# 3        2015-01-04
# 4        2015-01-04
#             ...
# 17409    2017-01-03
# 17410    2017-01-03
# 17411    2017-01-03
# 17412    2017-01-03
# 17413    2017-01-03
# Name: timestamp, Length: 17414, dtype: object

# %%
import datetime as dt
df["timestamp"] = pd.to_datetime(df["timestamp"])

# %%
df['hour'] = df.timestamp.dt.hour
df['day_of_month'] = df.timestamp.dt.day
df['day_of_week'] = df.timestamp.dt.dayofweek
df['month'] = df.timestamp.dt.month
df
# Out:
#                 timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0     2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1     2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2     2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3     2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4     2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...   ...  ...  ...    ...         ...           ...
# 17409 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season  hour  day_of_month  day_of_week  month
# 0             0.0         1.0     3.0     0             4            6      1
# 1             0.0         1.0     3.0     1             4            6      1
# 2             0.0         1.0     3.0     2             4            6      1
# 3             0.0         1.0     3.0     3             4            6      1
# 4             0.0         1.0     3.0     4             4            6      1
# ...           ...         ...     ...   ...           ...          ...    ...
# 17409         0.0         0.0     3.0    19             3            1      1
# 17410         0.0         0.0     3.0    20             3            1      1
# 17411         0.0         0.0     3.0    21             3            1      1
# 17412         0.0         0.0     3.0    22             3            1      1
# 17413         0.0         0.0     3.0    23             3            1      1
#
# [17414 rows x 14 columns]

# %%
# df['Date'] = pd.to_datetime(df['timestamp']).dt.date

# %%
# pd.to_datetime(df['timestamp']).dt.time

# %%
# df['Time'] = pd.to_datetime(df['timestamp']).dt.time

# %%
# df = df.drop('timestamp', axis =1)

# %%
df
# Out:
#                 timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0     2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1     2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2     2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3     2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4     2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...   ...  ...  ...    ...         ...           ...
# 17409 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season  hour  day_of_month  day_of_week  month
# 0             0.0         1.0     3.0     0             4            6      1
# 1             0.0         1.0     3.0     1             4            6      1
# 2             0.0         1.0     3.0     2             4            6      1
# 3             0.0         1.0     3.0     3             4            6      1
# 4             0.0         1.0     3.0     4             4            6      1
# ...           ...         ...     ...   ...           ...          ...    ...
# 17409         0.0         0.0     3.0    19             3            1      1
# 17410         0.0         0.0     3.0    20             3            1      1
# 17411         0.0         0.0     3.0    21             3            1      1
# 17412         0.0         0.0     3.0    22             3            1      1
# 17413         0.0         0.0     3.0    23             3            1      1
#
# [17414 rows x 14 columns]

# %%
#df2['weather_code'].astype('int')

# %%
# df2['weather_code'] = df2['weather_code'].astype('int')

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# hour            0
# day_of_month    0
# day_of_week     0
# month           0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
df.plot(kind = 'box', figsize=(16, 12))
# Out:
# <AxesSubplot:>

# %%
df.drop('cnt', 1).plot(kind = 'box', figsize=(16, 12))
# Out:
# <AxesSubplot:>

# %%
df['cnt'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4 = df.drop('timestamp', axis=1)

# %%
from sklearn.preprocessing import RobustScaler

robust = RobustScaler()
df_robust2 = robust.fit_transform(df4)

df_robust = pd.DataFrame(df_robust2)
df_robust.columns = df4.columns

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_log3 = scaler.fit_transform(df4)

df_scale2 = pd.DataFrame(df_log3)
df_scale2.columns = df4.columns

# %%
plt.figure(figsize=(12,10))
plt.subplot(3, 1, 1); sns.distplot(df['cnt'], kde = False)
plt.subplot(3, 1, 2); sns.distplot(df_robust['cnt'], kde = False)
plt.subplot(3, 1, 3); sns.distplot(df_scale2['cnt'], kde = False)

plt.show()

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x=df["timestamp"], y="cnt",data=df)
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='cnt'>

# %%
plt.figure(figsize=(15,7))
sns.barplot(x="month", y ="cnt", data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='cnt'>

# %%
fig,(ax1, ax2, ax3, ax4)= plt.subplots(nrows=4)
fig.set_size_inches(18, 15)

sns.pointplot(data=df, x='hour', y='cnt', ax=ax1)
sns.pointplot(data=df, x='hour', y='cnt', hue='is_holiday', ax=ax2)
sns.pointplot(data=df, x='hour', y='cnt', hue='is_weekend', ax=ax3)
sns.pointplot(data=df, x='hour', y='cnt', hue='season', ax=ax4);

# %%
fig,(ax1, ax2)= plt.subplots(nrows=2)
fig.set_size_inches(15,8)
sns.pointplot(data=df, x='day_of_week', y='cnt',ax=ax1)
sns.pointplot(x="day_of_week",y="cnt", data = df,hue="season",ax=ax2)
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='cnt'>

# %%
sns.barplot(x="season",y="cnt", data = df[df["is_holiday"]==1])
# Out:
# <AxesSubplot:xlabel='season', ylabel='cnt'>

# %%
df = df.set_index('timestamp',drop=True)
df.head()
# Out:
#                      cnt   t2    hum  wind_speed  weather_code  is_holiday  \
# timestamp
# 2015-01-04 00:00:00  182  2.0   93.0         6.0           3.0         0.0
# 2015-01-04 01:00:00  138  2.5   93.0         5.0           1.0         0.0
# 2015-01-04 02:00:00  134  2.5   96.5         0.0           1.0         0.0
# 2015-01-04 03:00:00   72  2.0  100.0         0.0           1.0         0.0
# 2015-01-04 04:00:00   47  0.0   93.0         6.5           1.0         0.0
#
#                      is_weekend  season  hour  day_of_month  day_of_week  \
# timestamp
# 2015-01-04 00:00:00         1.0     3.0     0             4            6
# 2015-01-04 01:00:00         1.0     3.0     1             4            6
# 2015-01-04 02:00:00         1.0     3.0     2             4            6
# 2015-01-04 03:00:00         1.0     3.0     3             4            6
# 2015-01-04 04:00:00         1.0     3.0     4             4            6
#
#                      month
# timestamp
# 2015-01-04 00:00:00      1
# 2015-01-04 01:00:00      1
# 2015-01-04 02:00:00      1
# 2015-01-04 03:00:00      1
# 2015-01-04 04:00:00      1

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season  hour  day_of_month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0     0             4
# 2015-01-04 01:00:00         0.0         1.0     3.0     1             4
# 2015-01-04 02:00:00         0.0         1.0     3.0     2             4
# 2015-01-04 03:00:00         0.0         1.0     3.0     3             4
# 2015-01-04 04:00:00         0.0         1.0     3.0     4             4
#
#                      day_of_week  month
# timestamp
# 2015-01-04 00:00:00            6      1
# 2015-01-04 01:00:00            6      1
# 2015-01-04 02:00:00            6      1
# 2015-01-04 03:00:00            6      1
# 2015-01-04 04:00:00            6      1

# %%
df.drop('t1', 1, inplace=True)

# %%
df.head(1)
# Out:
#             cnt   t2   hum  wind_speed  weather_code  is_holiday  is_weekend  \
# timestamp
# 2015-01-04  182  2.0  93.0         6.0           3.0         0.0         1.0
#
#             season  hour  day_of_month  day_of_week  month
# timestamp
# 2015-01-04     3.0     0             4            6      1

# %%
df
# Out:
#                       cnt   t2    hum  wind_speed  weather_code  is_holiday  \
# timestamp
# 2015-01-04 00:00:00   182  2.0   93.0         6.0           3.0         0.0
# 2015-01-04 01:00:00   138  2.5   93.0         5.0           1.0         0.0
# 2015-01-04 02:00:00   134  2.5   96.5         0.0           1.0         0.0
# 2015-01-04 03:00:00    72  2.0  100.0         0.0           1.0         0.0
# 2015-01-04 04:00:00    47  0.0   93.0         6.5           1.0         0.0
# ...                   ...  ...    ...         ...           ...         ...
# 2017-01-03 19:00:00  1042  1.0   81.0        19.0           3.0         0.0
# 2017-01-03 20:00:00   541  1.0   81.0        21.0           4.0         0.0
# 2017-01-03 21:00:00   337  1.5   78.5        24.0           4.0         0.0
# 2017-01-03 22:00:00   224  1.5   76.0        23.0           4.0         0.0
# 2017-01-03 23:00:00   139  1.0   76.0        22.0           2.0         0.0
#
#                      is_weekend  season  hour  day_of_month  day_of_week  \
# timestamp
# 2015-01-04 00:00:00         1.0     3.0     0             4            6
# 2015-01-04 01:00:00         1.0     3.0     1             4            6
# 2015-01-04 02:00:00         1.0     3.0     2             4            6
# 2015-01-04 03:00:00         1.0     3.0     3             4            6
# 2015-01-04 04:00:00         1.0     3.0     4             4            6
# ...                         ...     ...   ...           ...          ...
# 2017-01-03 19:00:00         0.0     3.0    19             3            1
# 2017-01-03 20:00:00         0.0     3.0    20             3            1
# 2017-01-03 21:00:00         0.0     3.0    21             3            1
# 2017-01-03 22:00:00         0.0     3.0    22             3            1
# 2017-01-03 23:00:00         0.0     3.0    23             3            1
#
#                      month
# timestamp
# 2015-01-04 00:00:00      1
# 2015-01-04 01:00:00      1
# 2015-01-04 02:00:00      1
# 2015-01-04 03:00:00      1
# 2015-01-04 04:00:00      1
# ...                    ...
# 2017-01-03 19:00:00      1
# 2017-01-03 20:00:00      1
# 2017-01-03 21:00:00      1
# 2017-01-03 22:00:00      1
# 2017-01-03 23:00:00      1
#
# [17414 rows x 12 columns]

# %%
train, test = df.iloc[0:int(len(df) * 0.9)], df.iloc[int(len(df) * 0.9):len(df)]

# %%
print(len(train), len(test))
# Out:
# 15672 1742

# %%
from sklearn.preprocessing import RobustScaler
rs = RobustScaler()

# %%
train[['t2', 'hum', 'wind_speed']] = rs.fit_transform(train[['t2', 'hum', 'wind_speed']])
test[['t2', 'hum', 'wind_speed']] = rs.transform(test[['t2', 'hum', 'wind_speed']])

# %%
def create_dataset(X, y, time_steps=10):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)        
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps = 10

# %%
X_train, y_train = create_dataset(train, train.cnt, time_steps)
X_test, y_test = create_dataset(test, test.cnt, time_steps)

print(X_train.shape, y_train.shape)
# Out:
# (15662, 10, 12) (15662,)

# %%
print(X_test.shape, y_test.shape)
# Out:
# (1732, 10, 12) (1732,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Dropout

# %% [markdown]
# ### Plot Train and Validation Losses

# %%
model = Sequential()

model.add(Bidirectional(LSTM(units=128,input_shape=(X_train.shape[1], X_train.shape[2]))))

model.add(Dropout(rate=0.2))

model.add(Dense(units=1))

model.compile(optimizer = 'adam', loss = 'mse')

# %%
model.fit(x = X_train, y = y_train, 
          validation_data = (X_test, y_test),
         batch_size = 128, epochs = 200)
# Out:
# Epoch 1/200
# 123/123 [==============================] - 3s 27ms/step - loss: 2522727.2500 - val_loss: 1691067.6250
# Epoch 2/200
# 123/123 [==============================] - 3s 24ms/step - loss: 2430519.7500 - val_loss: 1627393.0000
# Epoch 3/200
# 123/123 [==============================] - 3s 25ms/step - loss: 2358877.2500 - val_loss: 1573943.7500
# Epoch 4/200
# 123/123 [==============================] - 3s 26ms/step - loss: 2295474.2500 - val_loss: 1525080.1250
# Epoch 5/200
# 123/123 [==============================] - 4s 29ms/step - loss: 2234814.5000 - val_loss: 1478068.6250
# Epoch 6/200
# 123/123 [==============================] - 3s 28ms/step - loss: 2177431.0000 - val_loss: 1434084.7500
# Epoch 7/200
# 123/123 [==============================] - 4s 30ms/step - loss: 2122127.5000 - val_loss: 1391304.2500
# Epoch 8/200
# 123/123 [==============================] - 4s 31ms/step - loss: 2069256.6250 - val_loss: 1350770.7500
# Epoch 9/200
# 123/123 [==============================] - 6s 46ms/step - loss: 2018778.7500 - val_loss: 1312004.7500
# Epoch 10/200
# 123/123 [==============================] - 5s 39ms/step - loss: 1967209.8750 - val_loss: 1272495.1250
# Epoch 11/200
# 123/123 [==============================] - 5s 39ms/step - loss: 1918446.3750 - val_loss: 1236291.2500
# Epoch 12/200
# 123/123 [==============================] - 5s 39ms/step - loss: 1871827.2500 - val_loss: 1200575.0000
# Epoch 13/200
# 123/123 [==============================] - 5s 37ms/step - loss: 1825727.8750 - val_loss: 1166616.0000
# Epoch 14/200
# 123/123 [==============================] - 5s 38ms/step - loss: 1781513.2500 - val_loss: 1133596.0000
# Epoch 15/200
# 123/123 [==============================] - 5s 38ms/step - loss: 1738875.5000 - val_loss: 1102308.0000
# Epoch 16/200
# 123/123 [==============================] - 5s 37ms/step - loss: 1697007.6250 - val_loss: 1072008.0000
# Epoch 17/200
# 123/123 [==============================] - 5s 42ms/step - loss: 1656571.6250 - val_loss: 1042538.9375
# Epoch 18/200
# 123/123 [==============================] - 5s 39ms/step - loss: 1618476.1250 - val_loss: 1013840.5000
# Epoch 19/200
# 123/123 [==============================] - 4s 36ms/step - loss: 1580275.0000 - val_loss: 986675.7500
# Epoch 20/200
# 123/123 [==============================] - 4s 36ms/step - loss: 1543799.2500 - val_loss: 960418.8125
# Epoch 21/200
# 123/123 [==============================] - 4s 36ms/step - loss: 1507619.2500 - val_loss: 935019.7500
# Epoch 22/200
# 123/123 [==============================] - 4s 36ms/step - loss: 1473108.2500 - val_loss: 910901.5625
# Epoch 23/200
# 123/123 [==============================] - 5s 40ms/step - loss: 1439318.5000 - val_loss: 887059.4375
# Epoch 24/200
# 123/123 [==============================] - 5s 38ms/step - loss: 1407394.8750 - val_loss: 864361.6250
# Epoch 25/200
# 123/123 [==============================] - 4s 36ms/step - loss: 1374714.8750 - val_loss: 842332.0625
# Epoch 26/200
# 123/123 [==============================] - 5s 41ms/step - loss: 1344373.6250 - val_loss: 821858.5625
# Epoch 27/200
# 123/123 [==============================] - 4s 37ms/step - loss: 1312426.8750 - val_loss: 791312.1250
# Epoch 28/200
# 123/123 [==============================] - 4s 36ms/step - loss: 1277372.6250 - val_loss: 769702.9375
# Epoch 29/200
# 123/123 [==============================] - 4s 36ms/step - loss: 1243830.7500 - val_loss: 743315.1250
# Epoch 30/200
# 123/123 [==============================] - 5s 40ms/step - loss: 1210473.8750 - val_loss: 723350.6875
# Epoch 31/200
# 123/123 [==============================] - 5s 37ms/step - loss: 1179423.7500 - val_loss: 701354.5625
# Epoch 32/200
# 123/123 [==============================] - 5s 37ms/step - loss: 1149477.3750 - val_loss: 682280.6250
# Epoch 33/200
# 123/123 [==============================] - 5s 37ms/step - loss: 1122659.2500 - val_loss: 661254.8750
# Epoch 34/200
# 123/123 [==============================] - 5s 38ms/step - loss: 1092899.5000 - val_loss: 642928.5000
# Epoch 35/200
# 123/123 [==============================] - 4s 36ms/step - loss: 1067254.8750 - val_loss: 625183.1875
# Epoch 36/200
# 123/123 [==============================] - 5s 39ms/step - loss: 1041475.8750 - val_loss: 607591.4375
# Epoch 37/200
# 123/123 [==============================] - 5s 39ms/step - loss: 1015515.2500 - val_loss: 592142.0000
# Epoch 38/200
# 123/123 [==============================] - 5s 37ms/step - loss: 991322.6250 - val_loss: 575111.8125
# Epoch 39/200
# 123/123 [==============================] - 5s 37ms/step - loss: 967814.5000 - val_loss: 562039.1250
# Epoch 40/200
# 123/123 [==============================] - 5s 39ms/step - loss: 944228.9375 - val_loss: 545418.4375
# Epoch 41/200
# 123/123 [==============================] - 5s 37ms/step - loss: 923299.3750 - val_loss: 531538.3750
# Epoch 42/200
# 123/123 [==============================] - 5s 38ms/step - loss: 900213.3750 - val_loss: 518049.3438
# Epoch 43/200
# 123/123 [==============================] - 5s 39ms/step - loss: 879873.1875 - val_loss: 504088.3125
# Epoch 44/200
# 123/123 [==============================] - 5s 38ms/step - loss: 859929.7500 - val_loss: 491493.3438
# Epoch 45/200
# 123/123 [==============================] - 5s 38ms/step - loss: 839490.4375 - val_loss: 478775.7188
# Epoch 46/200
# 123/123 [==============================] - 5s 37ms/step - loss: 818962.6250 - val_loss: 467351.6875
# Epoch 47/200
# 123/123 [==============================] - 5s 39ms/step - loss: 800726.7500 - val_loss: 455713.1875
# Epoch 48/200
# 123/123 [==============================] - 5s 38ms/step - loss: 782981.4375 - val_loss: 443679.4375
# Epoch 49/200
# 123/123 [==============================] - 7s 57ms/step - loss: 763951.1250 - val_loss: 434214.0938
# Epoch 50/200
# 123/123 [==============================] - 6s 46ms/step - loss: 745647.3750 - val_loss: 423142.0000
# Epoch 51/200
# 123/123 [==============================] - 5s 38ms/step - loss: 729062.8750 - val_loss: 411405.3750
# Epoch 52/200
# 123/123 [==============================] - 6s 45ms/step - loss: 712242.8750 - val_loss: 402251.5938
# Epoch 53/200
# 123/123 [==============================] - 5s 40ms/step - loss: 695286.9375 - val_loss: 403887.5312
# Epoch 54/200
# 123/123 [==============================] - 5s 43ms/step - loss: 680031.3750 - val_loss: 383242.1875
# Epoch 55/200
# 123/123 [==============================] - 5s 39ms/step - loss: 664225.8750 - val_loss: 377362.0000
# Epoch 56/200
# 123/123 [==============================] - 5s 38ms/step - loss: 648728.0625 - val_loss: 365640.7188
# Epoch 57/200
# 123/123 [==============================] - 5s 38ms/step - loss: 634037.5625 - val_loss: 359050.0625
# Epoch 58/200
# 123/123 [==============================] - 5s 37ms/step - loss: 619670.1875 - val_loss: 347015.2500
# Epoch 59/200
# 123/123 [==============================] - 5s 38ms/step - loss: 604612.5625 - val_loss: 338721.2812
# Epoch 60/200
# 123/123 [==============================] - 5s 39ms/step - loss: 590491.5000 - val_loss: 335625.6562
# Epoch 61/200
# 123/123 [==============================] - 5s 40ms/step - loss: 578266.4375 - val_loss: 325143.8438
# Epoch 62/200
# 123/123 [==============================] - 5s 40ms/step - loss: 565201.1250 - val_loss: 314303.4062
# Epoch 63/200
# 123/123 [==============================] - 5s 37ms/step - loss: 552935.0625 - val_loss: 311931.0000
# Epoch 64/200
# 123/123 [==============================] - 5s 37ms/step - loss: 540102.7500 - val_loss: 302932.2500
# Epoch 65/200
# 123/123 [==============================] - 5s 39ms/step - loss: 527989.1250 - val_loss: 294031.4062
# Epoch 66/200
# 123/123 [==============================] - 7s 53ms/step - loss: 515943.7500 - val_loss: 290104.9062
# Epoch 67/200
# 123/123 [==============================] - 5s 42ms/step - loss: 504429.8438 - val_loss: 281738.0938
# Epoch 68/200
# 123/123 [==============================] - 5s 38ms/step - loss: 491973.4688 - val_loss: 273309.5000
# Epoch 69/200
# 123/123 [==============================] - 5s 38ms/step - loss: 478320.7188 - val_loss: 268779.0938
# Epoch 70/200
# 123/123 [==============================] - 5s 38ms/step - loss: 468273.8438 - val_loss: 257991.5156
# Epoch 71/200
# 123/123 [==============================] - 5s 38ms/step - loss: 454805.3750 - val_loss: 253485.6406
# Epoch 72/200
# 123/123 [==============================] - 5s 39ms/step - loss: 445801.9062 - val_loss: 244582.9844
# Epoch 73/200
# 123/123 [==============================] - 5s 38ms/step - loss: 434393.7188 - val_loss: 239042.8750
# Epoch 74/200
# 123/123 [==============================] - 5s 39ms/step - loss: 421678.9375 - val_loss: 230602.6719
# Epoch 75/200
# 123/123 [==============================] - 5s 40ms/step - loss: 410736.1250 - val_loss: 228284.7812
# Epoch 76/200
# 123/123 [==============================] - 5s 39ms/step - loss: 400569.6562 - val_loss: 219757.4375
# Epoch 77/200
# 123/123 [==============================] - 5s 39ms/step - loss: 391417.0625 - val_loss: 213656.3750
# Epoch 78/200
# 123/123 [==============================] - 5s 37ms/step - loss: 383580.8750 - val_loss: 206997.0000
# Epoch 79/200
# 123/123 [==============================] - 5s 43ms/step - loss: 371795.4375 - val_loss: 202045.0469
# Epoch 80/200
# 123/123 [==============================] - 5s 37ms/step - loss: 363223.4688 - val_loss: 199834.1250
# Epoch 81/200
# 123/123 [==============================] - 5s 37ms/step - loss: 355345.4375 - val_loss: 195065.5312
# Epoch 82/200
# 123/123 [==============================] - 4s 37ms/step - loss: 346758.8750 - val_loss: 188880.8750
# Epoch 83/200
# 123/123 [==============================] - 4s 36ms/step - loss: 337898.3438 - val_loss: 182463.1875
# Epoch 84/200
# 123/123 [==============================] - 5s 37ms/step - loss: 332306.8750 - val_loss: 177788.6875
# Epoch 85/200
# 123/123 [==============================] - 5s 41ms/step - loss: 323465.5625 - val_loss: 175968.6875
# Epoch 86/200
# 123/123 [==============================] - 5s 38ms/step - loss: 313955.8750 - val_loss: 171498.2188
# Epoch 87/200
# 123/123 [==============================] - 5s 37ms/step - loss: 307917.4688 - val_loss: 166434.4219
# Epoch 88/200
# 123/123 [==============================] - 5s 37ms/step - loss: 301562.1562 - val_loss: 162929.9219
# Epoch 89/200
# 123/123 [==============================] - 4s 36ms/step - loss: 292869.1875 - val_loss: 160786.9375
# Epoch 90/200
# 123/123 [==============================] - 4s 36ms/step - loss: 289242.8750 - val_loss: 158890.7500
# Epoch 91/200
# 123/123 [==============================] - 5s 37ms/step - loss: 284837.0000 - val_loss: 151627.0469
# Epoch 92/200
# 123/123 [==============================] - 5s 38ms/step - loss: 277539.4375 - val_loss: 159973.3750
# Epoch 93/200
# 123/123 [==============================] - 4s 36ms/step - loss: 277357.4688 - val_loss: 151474.9062
# Epoch 94/200
# 123/123 [==============================] - 5s 37ms/step - loss: 264559.3125 - val_loss: 140619.7656
# Epoch 95/200
# 123/123 [==============================] - 4s 35ms/step - loss: 259522.7969 - val_loss: 139437.6562
# Epoch 96/200
# 123/123 [==============================] - 4s 36ms/step - loss: 253216.1875 - val_loss: 133375.5312
# Epoch 97/200
# 123/123 [==============================] - 4s 36ms/step - loss: 246929.5781 - val_loss: 132907.3750
# Epoch 98/200
# 123/123 [==============================] - 5s 38ms/step - loss: 241091.8281 - val_loss: 126541.2031
# Epoch 99/200
# 123/123 [==============================] - 5s 39ms/step - loss: 234212.8125 - val_loss: 122386.8906
# Epoch 100/200
# 123/123 [==============================] - 4s 36ms/step - loss: 228892.2188 - val_loss: 127557.7422
# Epoch 101/200
# 123/123 [==============================] - 4s 36ms/step - loss: 224101.3281 - val_loss: 135708.8594
# Epoch 102/200
# 123/123 [==============================] - 5s 37ms/step - loss: 223402.6719 - val_loss: 116464.6953
# Epoch 103/200
# 123/123 [==============================] - 5s 37ms/step - loss: 212552.6406 - val_loss: 112630.6953
# Epoch 104/200
# 123/123 [==============================] - 4s 36ms/step - loss: 209235.7344 - val_loss: 109654.3594
# Epoch 105/200
# 123/123 [==============================] - 5s 38ms/step - loss: 203886.2031 - val_loss: 108317.6797
# Epoch 106/200
# 123/123 [==============================] - 5s 37ms/step - loss: 201649.4062 - val_loss: 113500.9609
# Epoch 107/200
# 123/123 [==============================] - 5s 37ms/step - loss: 196753.5625 - val_loss: 102632.3594
# Epoch 108/200
# 123/123 [==============================] - 4s 36ms/step - loss: 190457.8125 - val_loss: 101710.8516
# Epoch 109/200
# 123/123 [==============================] - 5s 37ms/step - loss: 186072.9375 - val_loss: 96253.5000
# Epoch 110/200
# 123/123 [==============================] - 4s 36ms/step - loss: 185013.0781 - val_loss: 97511.1328
# Epoch 111/200
# 123/123 [==============================] - 5s 38ms/step - loss: 178250.5156 - val_loss: 97631.3281
# Epoch 112/200
# 123/123 [==============================] - 5s 42ms/step - loss: 174289.8438 - val_loss: 92861.9922
# Epoch 113/200
# 123/123 [==============================] - 4s 36ms/step - loss: 168319.7031 - val_loss: 87599.5078
# Epoch 114/200
# 123/123 [==============================] - 5s 38ms/step - loss: 165631.9375 - val_loss: 83579.2812
# Epoch 115/200
# 123/123 [==============================] - 6s 50ms/step - loss: 160745.3281 - val_loss: 81170.9766
# Epoch 116/200
# 123/123 [==============================] - 5s 39ms/step - loss: 157584.2656 - val_loss: 82931.3438
# Epoch 117/200
# 123/123 [==============================] - 5s 41ms/step - loss: 154517.2812 - val_loss: 78690.6328
# Epoch 118/200
# 123/123 [==============================] - 5s 40ms/step - loss: 152804.8125 - val_loss: 75964.6328
# Epoch 119/200
# 123/123 [==============================] - 5s 37ms/step - loss: 152538.6875 - val_loss: 78963.6094
# Epoch 120/200
# 123/123 [==============================] - 5s 38ms/step - loss: 149274.9531 - val_loss: 77022.4297
# Epoch 121/200
# 123/123 [==============================] - 5s 38ms/step - loss: 148590.6562 - val_loss: 72387.1562
# Epoch 122/200
# 123/123 [==============================] - 5s 38ms/step - loss: 145664.3750 - val_loss: 73099.8359
# Epoch 123/200
# 123/123 [==============================] - 5s 37ms/step - loss: 141618.4688 - val_loss: 75481.6094
# Epoch 124/200
# 123/123 [==============================] - 5s 42ms/step - loss: 140858.1250 - val_loss: 76263.2969
# Epoch 125/200
# 123/123 [==============================] - 5s 40ms/step - loss: 137275.2188 - val_loss: 71887.0781
# Epoch 126/200
# 123/123 [==============================] - 5s 43ms/step - loss: 133744.7188 - val_loss: 66107.3672
# Epoch 127/200
# 123/123 [==============================] - 4s 36ms/step - loss: 129352.5859 - val_loss: 65779.0234
# Epoch 128/200
# 123/123 [==============================] - 5s 38ms/step - loss: 132278.6406 - val_loss: 65774.7500
# Epoch 129/200
# 123/123 [==============================] - 4s 36ms/step - loss: 129722.4922 - val_loss: 66177.6406
# Epoch 130/200
# 123/123 [==============================] - 5s 39ms/step - loss: 125905.2812 - val_loss: 62541.0117
# Epoch 131/200
# 123/123 [==============================] - 5s 37ms/step - loss: 120424.5391 - val_loss: 58494.7070
# Epoch 132/200
# 123/123 [==============================] - 5s 37ms/step - loss: 116893.9609 - val_loss: 57695.5273
# Epoch 133/200
# 123/123 [==============================] - 4s 36ms/step - loss: 118990.9688 - val_loss: 63698.7852
# Epoch 134/200
# 123/123 [==============================] - 5s 38ms/step - loss: 117576.9844 - val_loss: 57096.0430
# Epoch 135/200
# 123/123 [==============================] - 5s 38ms/step - loss: 116175.9219 - val_loss: 60338.0273
# Epoch 136/200
# 123/123 [==============================] - 5s 42ms/step - loss: 112543.1875 - val_loss: 56784.9922
# Epoch 137/200
# 123/123 [==============================] - 5s 40ms/step - loss: 114676.3359 - val_loss: 57160.7109
# Epoch 138/200
# 123/123 [==============================] - 5s 40ms/step - loss: 108168.4062 - val_loss: 53633.4258
# Epoch 139/200
# 123/123 [==============================] - 5s 41ms/step - loss: 105381.3359 - val_loss: 53964.4023
# Epoch 140/200
# 123/123 [==============================] - 5s 38ms/step - loss: 102617.2812 - val_loss: 49920.0156
# Epoch 141/200
# 123/123 [==============================] - 5s 38ms/step - loss: 101482.4453 - val_loss: 52313.0195
# Epoch 142/200
# 123/123 [==============================] - 5s 37ms/step - loss: 98050.4844 - val_loss: 50974.1797
# Epoch 143/200
# 123/123 [==============================] - 5s 38ms/step - loss: 97773.3906 - val_loss: 50246.8438
# Epoch 144/200
# 123/123 [==============================] - 5s 38ms/step - loss: 93905.3828 - val_loss: 47194.9336
# Epoch 145/200
# 123/123 [==============================] - 4s 36ms/step - loss: 94385.2500 - val_loss: 45827.9648
# Epoch 146/200
# 123/123 [==============================] - 5s 37ms/step - loss: 95146.6875 - val_loss: 43304.7578
# Epoch 147/200
# 123/123 [==============================] - 5s 37ms/step - loss: 103646.1484 - val_loss: 52210.9961
# Epoch 148/200
# 123/123 [==============================] - 5s 37ms/step - loss: 100211.0703 - val_loss: 49542.3320
# Epoch 149/200
# 123/123 [==============================] - 5s 41ms/step - loss: 97803.7500 - val_loss: 52285.2461
# Epoch 150/200
# 123/123 [==============================] - 5s 41ms/step - loss: 94669.1641 - val_loss: 47302.2969
# Epoch 151/200
# 123/123 [==============================] - 5s 38ms/step - loss: 91811.2891 - val_loss: 48692.1953
# Epoch 152/200
# 123/123 [==============================] - 5s 38ms/step - loss: 88837.3516 - val_loss: 42229.1914
# Epoch 153/200
# 123/123 [==============================] - 4s 37ms/step - loss: 89725.3906 - val_loss: 44757.5625
# Epoch 154/200
# 123/123 [==============================] - 5s 38ms/step - loss: 91076.2188 - val_loss: 42966.1523
# Epoch 155/200
# 123/123 [==============================] - 5s 37ms/step - loss: 89766.5312 - val_loss: 40290.0078
# Epoch 156/200
# 123/123 [==============================] - 5s 38ms/step - loss: 85709.3672 - val_loss: 42342.8711
# Epoch 157/200
# 123/123 [==============================] - 5s 38ms/step - loss: 84406.2422 - val_loss: 37359.5898
# Epoch 158/200
# 123/123 [==============================] - 4s 36ms/step - loss: 83012.3984 - val_loss: 39571.7500
# Epoch 159/200
# 123/123 [==============================] - 5s 37ms/step - loss: 90172.1094 - val_loss: 41211.2891
# Epoch 160/200
# 123/123 [==============================] - 4s 36ms/step - loss: 85328.3672 - val_loss: 39553.8164
# Epoch 161/200
# 123/123 [==============================] - 5s 40ms/step - loss: 83730.7109 - val_loss: 39919.8750
# Epoch 162/200
# 123/123 [==============================] - 5s 39ms/step - loss: 82263.6016 - val_loss: 34677.3633
# Epoch 163/200
# 123/123 [==============================] - 5s 40ms/step - loss: 82378.9297 - val_loss: 35579.9336
# Epoch 164/200
# 123/123 [==============================] - 5s 37ms/step - loss: 80649.2188 - val_loss: 41577.7305
# Epoch 165/200
# 123/123 [==============================] - 5s 39ms/step - loss: 81836.8672 - val_loss: 37287.3750
# Epoch 166/200
# 123/123 [==============================] - 4s 36ms/step - loss: 79386.5312 - val_loss: 31284.7363
# Epoch 167/200
# 123/123 [==============================] - 4s 36ms/step - loss: 80987.6094 - val_loss: 33875.5469
# Epoch 168/200
# 123/123 [==============================] - 5s 39ms/step - loss: 78650.0938 - val_loss: 37355.7734
# Epoch 169/200
# 123/123 [==============================] - 5s 38ms/step - loss: 78540.4766 - val_loss: 32203.0156
# Epoch 170/200
# 123/123 [==============================] - 5s 38ms/step - loss: 75969.3438 - val_loss: 33285.5781
# Epoch 171/200
# 123/123 [==============================] - 4s 36ms/step - loss: 75129.5938 - val_loss: 31390.3770
# Epoch 172/200
# 123/123 [==============================] - 4s 36ms/step - loss: 74616.6797 - val_loss: 29911.2773
# Epoch 173/200
# 123/123 [==============================] - 5s 37ms/step - loss: 72850.4531 - val_loss: 34151.8281
# Epoch 174/200
# 123/123 [==============================] - 5s 38ms/step - loss: 71323.5234 - val_loss: 32008.4531
# Epoch 175/200
# 123/123 [==============================] - 5s 43ms/step - loss: 69381.4141 - val_loss: 28317.6973
# Epoch 176/200
# 123/123 [==============================] - 5s 38ms/step - loss: 68026.5547 - val_loss: 32557.2773
# Epoch 177/200
# 123/123 [==============================] - 5s 38ms/step - loss: 68203.4219 - val_loss: 33773.2734
# Epoch 178/200
# 123/123 [==============================] - 5s 38ms/step - loss: 71280.6406 - val_loss: 27486.4180
# Epoch 179/200
# 123/123 [==============================] - 5s 38ms/step - loss: 69925.0781 - val_loss: 30793.2832
# Epoch 180/200
# 123/123 [==============================] - 4s 36ms/step - loss: 69332.0156 - val_loss: 31022.6816
# Epoch 181/200
# 123/123 [==============================] - 5s 38ms/step - loss: 66746.1250 - val_loss: 27936.4609
# Epoch 182/200
# 123/123 [==============================] - 5s 37ms/step - loss: 66963.0078 - val_loss: 28703.1426
# Epoch 183/200
# 123/123 [==============================] - 5s 39ms/step - loss: 68976.2188 - val_loss: 26526.2812
# Epoch 184/200
# 123/123 [==============================] - 4s 36ms/step - loss: 72108.0234 - val_loss: 30201.5273
# Epoch 185/200
# 123/123 [==============================] - 4s 36ms/step - loss: 72265.6094 - val_loss: 31578.1719
# Epoch 186/200
# 123/123 [==============================] - 5s 37ms/step - loss: 73027.4688 - val_loss: 28050.5469
# Epoch 187/200
# 123/123 [==============================] - 5s 38ms/step - loss: 70445.0234 - val_loss: 31061.4512
# Epoch 188/200
# 123/123 [==============================] - 5s 40ms/step - loss: 68881.0469 - val_loss: 27569.3203
# Epoch 189/200
# 123/123 [==============================] - 5s 37ms/step - loss: 71095.2656 - val_loss: 30047.8594
# Epoch 190/200
# 123/123 [==============================] - 5s 37ms/step - loss: 69850.4062 - val_loss: 33105.4766
# Epoch 191/200
# 123/123 [==============================] - 5s 39ms/step - loss: 68016.1719 - val_loss: 26304.2422
# Epoch 192/200
# 123/123 [==============================] - 5s 37ms/step - loss: 70027.5703 - val_loss: 30859.9375
# Epoch 193/200
# 123/123 [==============================] - 4s 36ms/step - loss: 68561.8984 - val_loss: 25970.0293
# Epoch 194/200
# 123/123 [==============================] - 5s 40ms/step - loss: 66600.5156 - val_loss: 30669.4609
# Epoch 195/200
# 123/123 [==============================] - 5s 42ms/step - loss: 64768.6328 - val_loss: 27596.9375
# Epoch 196/200
# 123/123 [==============================] - 5s 39ms/step - loss: 68038.4844 - val_loss: 27158.2148
# Epoch 197/200
# 123/123 [==============================] - 5s 44ms/step - loss: 75788.4453 - val_loss: 27731.7461
# Epoch 198/200
# 123/123 [==============================] - 5s 42ms/step - loss: 70913.4297 - val_loss: 28612.2734
# Epoch 199/200
# 123/123 [==============================] - 6s 46ms/step - loss: 66801.7734 - val_loss: 28529.3379
# Epoch 200/200
# 123/123 [==============================] - 6s 46ms/step - loss: 65590.3906 - val_loss: 26082.9375

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Demand Predictions

# %%
y_pred = model.predict(X_test)

# %%
plt.figure(figsize=(20,5))
plt.plot(np.arange(0, len(y_train)), y_train.flatten(), 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test.flatten(), marker='.', label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred.flatten(), 'r', label="prediction")
plt.ylabel('Bike Count')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
plt.figure(figsize=(15,5))
plt.plot(y_test.flatten(), marker='.', label="true")
plt.plot(y_pred.flatten(), 'r', label="prediction")
plt.ylabel('Bike Count')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
print('R2 Score: ', r2_score(y_test, y_pred))
print('MAE: ', mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score:  0.969735833526676
# MAE:  100.03726084458084
