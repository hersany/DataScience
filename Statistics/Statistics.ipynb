# %%
salary = [102, 33, 26, 27, 30, 25, 33, 33, 24]
import numpy as np
from scipy import stats

# %%
mean_salary = np.mean(salary)
print('Mean :', mean_salary)
# Out:
# Mean : 37.0

# %%
median_salary = np.median(salary)
print('Median :', median_salary)
# Out:
# Median : 30.0

# %%
stats.iqr(salary)
# Out:
# 7.0

# %%
mode_salary = stats.mode(salary)
print('Mode :', mode_salary)
# Out:
# Mode : ModeResult(mode=array([33]), count=array([3]))

# %%
print('Range :', (np.max(salary) - (np.min(salary))))
# Out:
# Range : 78

# %%
print('Variance :', (np.var(salary)))
# Out:
# Variance : 539.5555555555555

# %%
print('Std :', (np.std(salary)))
# Out:
# Std : 23.22833518691246

# %%
a = [1, 10, 7, 12, 0, 30, 15, 22, 8, 2]
print(np.std(a))
# Out:
# 9.089004345911603

# %%
import numpy as np

# %%
temp = [93, 84, 82, 78, 98, 70]
number_of_people = [13, 10, 11, 8, 15, 9]

# %%
print('Coveriance :', np.cov(temp, number_of_people))
# Out:
# Coveriance : [[102.56666667  24.        ]
#  [ 24.           6.8       ]]

# %%
print('Correlation :', np.corrcoef(temp, number_of_people))
# Out:
# Correlation : [[1.         0.90876934]
#  [0.90876934 1.        ]]

# %%
import numpy as np

# %%
np.random.seed(101)
population = np.random.randint(0, 80, 100000)

# %%
population
# Out:
# array([11, 70, 63, ..., 44, 30, 77])

# %%
len(population)
# Out:
# 100000

# %%
np.random.seed(101)
sample = np.random.choice(population, 100)

# %%
sample
# Out:
# array([43, 40, 68, 14,  9, 56, 39, 10, 67,  6, 53, 62, 50, 73, 18, 40, 74,
#        50, 60, 28, 13, 74, 18, 44, 27, 58, 63, 17,  6, 64, 66, 20,  8, 70,
#        79, 61, 32, 70, 51, 61, 75, 48, 39,  7, 14, 58, 56, 50, 73, 57, 31,
#        54, 11, 37, 45, 53, 26, 57, 52, 67, 45,  5, 75, 23, 32,  8, 59, 71,
#        10, 48, 16, 75, 32, 23, 37, 77, 33, 71, 62, 71, 46, 19, 24, 63, 33,
#        31, 39, 22, 19,  6, 60, 62, 67, 38, 59,  0, 32, 35,  2, 52])

# %%
len(sample)
# Out:
# 100

# %%
population.mean()
# Out:
# 39.42698

# %%
sample.mean()
# Out:
# 35.23

# %%
np.random.seed(101)
for i in range(10):
    sample = np.random.choice(population, 100)
    print(sample.mean())
# Out:
# 42.54
# 41.4
# 36.39
# 42.9
# 43.59
# 38.12
# 39.99
# 36.32
# 38.23
# 35.23

# %%
np.random.seed(101)
sample_means = []
for i in range(10):
    sample = np.random.choice(population, 100)
    sample_means.append(sample.mean())

# %%
sample_means
# Out:
# [42.54, 41.4, 36.39, 42.9, 43.59, 38.12, 39.99, 36.32, 38.23, 35.23]

# %%
np.mean(sample_means)
# Out:
# 39.471000000000004

# %%
population.mean()
# Out:
# 39.42698

# %%
from scipy.stats import kurtosis, skew

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.3.1-cp37-cp37m-manylinux1_x86_64.whl (11.6 MB)
#      |████████████████████████████████| 11.6 MB 853 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.1 in /snap/jupyter/6/lib/python3.7/site-packages (from matplotlib) (2.8.0)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 998 kB/s eta 0:00:01
# Collecting certifi>=2020.06.20
#   Downloading certifi-2020.6.20-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 905 kB/s eta 0:00:01
# Collecting pillow>=6.2.0
#   Downloading Pillow-7.2.0-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15 in /home/navarra/snap/jupyter/common/lib/python3.7/site-packages (from matplotlib) (1.18.5)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.2.0-cp37-cp37m-manylinux1_x86_64.whl (88 kB)
#      |████████████████████████████████| 88 kB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /snap/jupyter/6/lib/python3.7/site-packages (from python-dateutil>=2.1->matplotlib) (1.12.0)
# Installing collected packages: cycler, pyparsing, certifi, pillow, kiwisolver, matplotlib
# Successfully installed certifi-2020.6.20 cycler-0.10.0 kiwisolver-1.2.0 matplotlib-3.3.1 pillow-7.2.0 pyparsing-2.4.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
x = np.random.normal(0, 2, 100000)

# %%
plt.hist(x, bins = 100);

# %%
kurtosis(x)
# Out:
# -0.00803694939848043

# %%
skew(x)
# Out:
# -0.0017603763521919207

# %%
import numpy as np
from scipy import stats

# %%
age = [20, 22, 25, 25, 27, 27, 29, 30, 31, 121]

# %%
np.mean(age)
# Out:
# 35.7

# %%
np.median(age)
# Out:
# 27.0

# %%
stats.mode(age)
# Out:
# ModeResult(mode=array([25]), count=array([2]))

# %%
stats.mode(age)[0]
# Out:
# array([25])

# %%
stats.mode(age)[0][0]
# Out:
# 25

# %%
age_2 = [20, 22, 25, 25, 27, 27, 29, 30, 31]

# %%
np.mean(age_2)
# Out:
# 26.22222222222222

# %%
np.median(age_2)
# Out:
# 27.0

# %%
age_3 = [19, 20, 21, 22]

# %%
stats.mode(age_3)   # it gives smallest element if no duplicate or more.
# Out:
# ModeResult(mode=array([19]), count=array([1]))

# %%
type(age)
# Out:
# list

# %%
# mean in arrays
age_new = np.array(age)

# %%
age_new
# Out:
# array([ 20,  22,  25,  25,  27,  27,  29,  30,  31, 121])

# %%
type(age_new)
# Out:
# numpy.ndarray

# %%
age_new.mean()
# Out:
# 35.7

# %%
a = np.array([[6, 8, 3, 0],
              [3, 2, 1, 7],
              [8, 1, 8, 4],
              [5, 3, 0, 5],
              [4, 7, 5, 9]])
stats.mode(a)
# Out:
# ModeResult(mode=array([[3, 1, 0, 0]]), count=array([[1, 1, 1, 1]]))

# %%
stats.mode(a, axis = 1)
# Out:
# ModeResult(mode=array([[0],
#        [1],
#        [8],
#        [5],
#        [4]]), count=array([[1],
#        [1],
#        [2],
#        [2],
#        [1]]))

# %%
# range, sd, variance
age = [20, 22, 25, 25, 27, 27, 27, 29, 30, 31, 121]

# %%
range = np.max(age) - np.min(age)
print(range)
# Out:
# 101

# %%
np.ptp(age)   # it gives range Peak To Peak ptp
# Out:
# 101

# %%
np.std(age)
# Out:
# 27.400910885504736

# %%
np.var(age)
# Out:
# 750.809917355372

# %%
age_2 = [20, 22, 25, 25, 27, 27, 27, 29, 30, 31]

# %%
np.std(age_2)
# Out:
# 3.2572994949804666

# %%
range = np.max(age_2) - np.min(age_2)

# %%
print(range)
# Out:
# 11

# %%
# IQR - iqr

# %%
x=[8, 10, 5, 24, 8, 3, 11, 3, 40, 7, 6, 12, 4]

# %%
q75, q25 = np.percentile(x, [75, 25])

# %%
q75
# Out:
# 11.0

# %%
q25
# Out:
# 5.0

# %%
sorted(x)
# Out:
# [3, 3, 4, 5, 6, 7, 8, 8, 10, 11, 12, 24, 40]

# %%
iqr = q75-q25

# %%
iqr
# Out:
# 6.0

# %%
stats.iqr(x)
# Out:
# 6.0

# %%
np.percentile(x, 75)
# Out:
# 11.0

# %%
np.percentile(x, 25)
# Out:
# 5.0

# %%
q = [62, 63, 64, 64, 70, 72, 76, 77, 81, 81]

# %%
from scipy import stats
import numpy as np

# %%
np.percentile(q, 25)
# Out:
# 64.0

# %%
np.percentile(q, 75)
# Out:
# 76.75

# %%
stats.iqr(q)
# Out:
# 12.75

# %%
np.median(q)
# Out:
# 71.0

# %%
np.mean(q)
# Out:
# 71.0

# %%
stats.mode(q)
# Out:
# ModeResult(mode=array([64]), count=array([2]))

# %%
# scatter plot

# %%
# method matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5, 11)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x ** 2

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y);   # line plot

# %%
plt.scatter(x, y);  #scatter plot

# %%
np.cov(x, y)
# Out:
# array([[ 2.75  , 13.75  ],
#        [13.75  , 74.1125]])

# %%
# method seaborn

# %%
import seaborn as sns

# %%
sns.scatterplot(x, y);

# %%
sns.jointplot(x, y, kind = 'scatter');

# %%
# method pandas

# %%
import pandas as pd

# %%
lst = zip(x, y)
print(list((lst)))
df = pd.DataFrame(lst, columns = ['x', 'y'])
# Out:
# [(0.0, 0.0), (0.5, 0.25), (1.0, 1.0), (1.5, 2.25), (2.0, 4.0), (2.5, 6.25), (3.0, 9.0), (3.5, 12.25), (4.0, 16.0), (4.5, 20.25), (5.0, 25.0)]

# %%
df.head()
# Out:
#      x     y
# 0  0.0  0.00
# 1  0.5  0.25
# 2  1.0  1.00
# 3  1.5  2.25
# 4  2.0  4.00

# %%
df.plot.scatter('x', 'y');

# %%
# method changing linestyle in line plot

# %%
plt.plot(x, y);

# %%
plt.plot(x, y, marker = 'o', linestyle = ' ');

# %%
# boxplot

# %%
# boxplot with matplotlib

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.boxplot(x);

# %%
arr1 = np.random.randint(100, 200, 100)

# %%
arr1
# Out:
# array([180, 171, 144, 179, 129, 177, 177, 138, 193, 132, 113, 180, 184,
#        112, 176, 130, 189, 115, 143, 191, 175, 105, 158, 189, 196, 174,
#        194, 113, 143, 192, 192, 192, 147, 152, 155, 124, 153, 191, 127,
#        152, 134, 115, 130, 165, 140, 118, 178, 136, 112, 128, 162, 133,
#        174, 161, 146, 116, 120, 176, 182, 108, 160, 122, 150, 130, 170,
#        158, 189, 139, 196, 197, 190, 166, 123, 184, 175, 118, 187, 107,
#        111, 143, 181, 161, 194, 110, 103, 126, 184, 164, 116, 101, 147,
#        181, 191, 113, 124, 123, 140, 178, 197, 126])

# %%
plt.boxplot(arr1);

# %%
arr1=np.random.randint(100,200,100)
arr2=np.random.randint(1,50,5)
arr3=np.random.randint(300,350,5)
arr=np.append(arr1, arr2)
arr=np.append(arr, arr3)
plt.boxplot(arr);

# %%
min(arr)
# Out:
# 2

# %%
max(arr)
# Out:
# 342

# %%
from scipy import stats

# %%
stats.iqr(arr)
# Out:
# 47.25

# %%
np.percentile(arr, 25)
# Out:
# 125.0

# %%
np.percentile(arr, 75)
# Out:
# 172.25

# %%
np.median(arr)
# Out:
# 149.0

# %%
sns.boxplot(arr, orient = 'v');

# %%
# corr and cov

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
temp=[93,84,82,78,98,70]
number_of_people=[13,10, 11, 8, 15, 9]

# %%
np.cov(temp, number_of_people)[0, 1]
# Out:
# 24.0

# %%
np.corrcoef(temp, number_of_people)[0, 1]
# Out:
# 0.9087693361896165

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.corr('pearson')
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
np.corrcoef(df['total_bill'], df['tip'])[0, 1]
# Out:
# 0.6757341092113641

# %%
df['total_bill'].corr(df['tip'])
# Out:
# 0.6757341092113641

# %%
sns.heatmap(tips.corr(), annot = True, cmap = 'RdYlGn');

# %%
mpg = sns.load_dataset('mpg')

# %%
sns.pairplot(mpg);
