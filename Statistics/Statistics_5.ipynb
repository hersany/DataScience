# %% [markdown]
# # CENTRAL LIMIT THEOREM

# %% [markdown]
# ## Sample Mean for a Uniform Distribution

# %%
import random
import math
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
random.seed(54312)

# %%
sample_size = 30

sim_num = 10000

# %%
mean_list = []

for i in range(sim_num):
    sample_list = []
    for i in range(sample_size):
        sample_list.append(random.randint(0, 100))
    sample_mean = sum(sample_list)/sample_size
    mean_list.append(sample_mean)

# %%
mean_list
# Out:
# [54.3,
#  54.9,
#  55.1,
#  48.13333333333333,
#  52.03333333333333,
#  46.233333333333334,
#  53.1,
#  52.13333333333333,
#  49.333333333333336,
#  46.6,
#  46.13333333333333,
#  47.5,
#  58.86666666666667,
#  51.86666666666667,
#  46.7,
#  40.7,
#  54.166666666666664,
#  48.3,
#  57.766666666666666,
#  56.03333333333333,
#  57.0,
#  57.5,
#  47.93333333333333,
#  57.2,
#  58.56666666666667,
#  56.2,
#  59.03333333333333,
#  56.733333333333334,
#  44.8,
#  48.13333333333333,
#  55.666666666666664,
#  42.93333333333333,
#  51.266666666666666,
#  50.6,
#  50.766666666666666,
#  43.666666666666664,
#  48.2,
#  49.8,
#  50.0,
#  44.36666666666667,
#  47.1,
#  48.666666666666664,
#  53.1,
#  48.666666666666664,
#  57.9,
#  50.6,
#  48.666666666666664,
#  39.166666666666664,
#  46.2,
#  46.93333333333333,
#  52.96666666666667,
#  46.333333333333336,
#  56.0,
#  54.5,
#  49.833333333333336,
#  50.833333333333336,
#  34.46666666666667,
#  52.333333333333336,
#  54.333333333333336,
#  58.13333333333333,
#  52.333333333333336,
#  55.36666666666667,
#  44.2,
#  47.2,
#  57.266666666666666,
#  45.733333333333334,
#  53.333333333333336,
#  51.1,
#  49.333333333333336,
#  53.56666666666667,
#  53.266666666666666,
#  54.9,
#  55.46666666666667,
#  51.3,
#  42.0,
#  51.63333333333333,
#  54.96666666666667,
#  43.3,
#  43.5,
#  61.8,
#  56.766666666666666,
#  46.43333333333333,
#  52.36666666666667,
#  50.5,
#  55.333333333333336,
#  44.2,
#  58.2,
#  60.13333333333333,
#  60.733333333333334,
#  39.1,
#  43.63333333333333,
#  52.233333333333334,
#  56.166666666666664,
#  57.63333333333333,
#  58.166666666666664,
#  52.8,
#  42.96666666666667,
#  49.6,
#  40.266666666666666,
#  50.266666666666666,
#  43.56666666666667,
#  55.46666666666667,
#  51.1,
#  51.666666666666664,
#  59.4,
#  56.1,
#  39.63333333333333,
#  56.1,
#  41.1,
#  51.03333333333333,
#  50.766666666666666,
#  55.0,
#  55.13333333333333,
#  51.06666666666667,
#  53.7,
#  54.96666666666667,
#  49.266666666666666,
#  57.733333333333334,
#  42.8,
#  49.733333333333334,
#  53.733333333333334,
#  47.0,
#  50.1,
#  48.3,
#  48.8,
#  57.13333333333333,
#  52.6,
#  49.6,
#  50.06666666666667,
#  36.4,
#  47.3,
#  52.56666666666667,
#  40.2,
#  36.96666666666667,
#  52.53333333333333,
#  42.93333333333333,
#  46.666666666666664,
#  46.4,
#  46.1,
#  53.3,
#  52.03333333333333,
#  56.233333333333334,
#  51.63333333333333,
#  45.766666666666666,
#  50.8,
#  50.43333333333333,
#  53.53333333333333,
#  45.4,
#  42.9,
#  54.03333333333333,
#  52.6,
#  62.4,
#  48.93333333333333,
#  40.766666666666666,
#  54.63333333333333,
#  49.53333333333333,
#  51.3,
#  50.53333333333333,
#  54.666666666666664,
#  50.93333333333333,
#  48.8,
#  59.833333333333336,
#  40.8,
#  48.266666666666666,
#  50.36666666666667,
#  59.96666666666667,
#  53.43333333333333,
#  46.96666666666667,
#  51.06666666666667,
#  59.0,
#  41.8,
#  55.266666666666666,
#  46.3,
#  48.666666666666664,
#  46.63333333333333,
#  39.266666666666666,
#  60.766666666666666,
#  42.53333333333333,
#  49.333333333333336,
#  57.0,
#  49.5,
#  48.666666666666664,
#  50.233333333333334,
#  53.1,
#  51.06666666666667,
#  49.233333333333334,
#  46.03333333333333,
#  44.43333333333333,
#  42.7,
#  50.3,
#  59.1,
#  40.46666666666667,
#  37.9,
#  58.8,
#  45.9,
#  43.7,
#  45.5,
#  44.86666666666667,
#  49.8,
#  46.56666666666667,
#  53.43333333333333,
#  48.266666666666666,
#  53.833333333333336,
#  43.2,
#  44.36666666666667,
#  44.96666666666667,
#  52.733333333333334,
#  42.96666666666667,
#  43.0,
#  47.03333333333333,
#  56.1,
#  49.9,
#  49.4,
#  50.666666666666664,
#  48.266666666666666,
#  48.833333333333336,
#  52.36666666666667,
#  44.6,
#  53.266666666666666,
#  58.56666666666667,
#  57.166666666666664,
#  46.86666666666667,
#  50.233333333333334,
#  48.0,
#  53.53333333333333,
#  50.36666666666667,
#  48.766666666666666,
#  62.2,
#  54.13333333333333,
#  59.36666666666667,
#  44.0,
#  51.1,
#  52.333333333333336,
#  39.5,
#  54.56666666666667,
#  43.233333333333334,
#  53.63333333333333,
#  47.266666666666666,
#  52.36666666666667,
#  52.93333333333333,
#  54.7,
#  58.56666666666667,
#  46.9,
#  56.5,
#  51.833333333333336,
#  52.6,
#  52.43333333333333,
#  57.56666666666667,
#  54.03333333333333,
#  48.86666666666667,
#  58.4,
#  47.36666666666667,
#  61.9,
#  52.6,
#  47.3,
#  57.2,
#  51.4,
#  45.766666666666666,
#  49.53333333333333,
#  54.36666666666667,
#  52.6,
#  54.7,
#  44.06666666666667,
#  50.03333333333333,
#  49.9,
#  38.43333333333333,
#  45.36666666666667,
#  43.1,
#  46.63333333333333,
#  48.13333333333333,
#  50.13333333333333,
#  53.13333333333333,
#  47.666666666666664,
#  44.833333333333336,
#  54.2,
#  47.06666666666667,
#  54.766666666666666,
#  52.43333333333333,
#  52.3,
#  47.7,
#  51.266666666666666,
#  57.53333333333333,
#  50.86666666666667,
#  45.9,
#  49.1,
#  54.5,
#  53.53333333333333,
#  47.2,
#  52.1,
#  47.93333333333333,
#  55.1,
#  44.833333333333336,
#  49.4,
#  48.266666666666666,
#  52.5,
#  49.13333333333333,
#  53.43333333333333,
#  50.8,
#  40.8,
#  51.43333333333333,
#  44.4,
#  55.1,
#  50.13333333333333,
#  55.8,
#  57.96666666666667,
#  47.766666666666666,
#  51.8,
#  52.43333333333333,
#  47.333333333333336,
#  57.233333333333334,
#  46.96666666666667,
#  46.93333333333333,
#  52.1,
#  46.06666666666667,
#  52.233333333333334,
#  49.166666666666664,
#  51.96666666666667,
#  52.233333333333334,
#  49.9,
#  36.96666666666667,
#  56.06666666666667,
#  49.733333333333334,
#  44.1,
#  50.63333333333333,
#  56.9,
#  ...]

# %%
sum(mean_list)/len(mean_list)
# Out:
# 50.086843333333206

# %%
plt.hist(mean_list, bins=100, density = True, color = 'r');
plt.grid()
mu = 50
sigma = math.sqrt((100**2)/12) / (math.sqrt(sample_size))
x = np.linspace(mu - 4* sigma, mu + 4 * sigma)
plt.plot(x, stats.norm.pdf(x, mu, sigma))

# %% [markdown]
# ## Sample Mean for a Exponential Distribution

# %%
sample_size = 30

sim_num = 10000

# %%
mean_list = []

for i in range(sim_num):
    sample_list = []
    for i in range(sample_size):
        sample_list.append(np.random.exponential(1))
    sample_mean = sum(sample_list)/sample_size
    mean_list.append(sample_mean)

# %%
plt.hist(mean_list, bins=100, density = True, color = 'r');
plt.grid()
mu = 1
sigma = 1 / (math.sqrt(sample_size))
x = np.linspace(mu - 4* sigma, mu + 4 * sigma)
plt.plot(x, stats.norm.pdf(x, mu, sigma))

# %% [markdown]
# ## CONFIDENCE INTERVAL

# %%
import random
import math
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
random.seed(39809)

# %%
sample_size = 30
sample_list = []

for i in range(30):
    sample_list.append(random.randint(0, 10))

# %%
sample_mean = np.mean(sample_list)

# %%
sample_mean
# Out:
# 5.0

# %%
n = len(sample_list)

# %%
cl = 0.95

std = 1

# %%
critic_value = stats.norm.ppf(((1-0.95)/2) + 0.95)

# %%
(((1-0.95)/2) + 0.95)   # z table ppf value for 0.95 at t table
# Out:
# 0.975

# %%
critic_value
# Out:
# 1.959963984540054

# %%
lower_limit = sample_mean - (critic_value * (std/math.sqrt(n)))

# %%
upper_limit = sample_mean + (critic_value * (std/math.sqrt(n)))

# %%
print(f'Your {cl} z confidence interval is ({lower_limit:.2f}, {upper_limit:.2f})')
# Out:
# Your 0.95 z confidence interval is (4.64, 5.36)

# %% [markdown]
# Exercise

# %%
sample_list = [2, 3, 5, 6, 9]

# %%
sample_mean = np.mean(sample_list)

sample_mean
# Out:
# 5.0

# %%
std = 2.5

# %%
n = len(sample_list)

# %%
cl = 0.95

# %%
critic_value = stats.norm.ppf(((1 - cl)/2) + cl)

# %%
critic_value
# Out:
# 1.959963984540054

# %%
lower_limit = sample_mean - (critic_value * (std/math.sqrt(n)))

# %%
upper_limit = sample_mean + (critic_value * (std/math.sqrt(n)))

# %%
print(f'Your {cl} z confidence interval is ({lower_limit:.2f}, {upper_limit:.2f})')
# Out:
# Your 0.95 z confidence interval is (2.81, 7.19)

# %%
stats.norm.interval(cl, loc = sample_mean, scale = std/math.sqrt(n))   # using scipy
# Out:
# (2.808693648558546, 7.191306351441455)

# %%
critic_value = stats.norm.ppf(((1 - 0.99)/2) + 0.99)  # interval gets larger beacuse CL gets higher

# %%
lower_limit = sample_mean - (critic_value * (std/math.sqrt(n)))

# %%
upper_limit = sample_mean + (critic_value * (std/math.sqrt(n)))

# %%
print(f'Your {cl} z confidence interval is ({lower_limit:.2f}, {upper_limit:.2f})')   # interval gets larger
# Out:
# Your 0.95 z confidence interval is (2.12, 7.88)

# %%
stats.norm.interval(0.99, loc = sample_mean, scale = std/math.sqrt(n))
# Out:
# (2.120135289414359, 7.879864710585641)

# %% [markdown]
# ## USING SCIPY

# %%
stats.norm.interval(cl, loc = sample_mean, scale = std/math.sqrt(n))   # using scipy
# Out:
# (2.808693648558546, 7.191306351441455)
