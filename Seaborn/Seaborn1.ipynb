# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize = (12, 8))
plt.scatter(x = 'total_bill', y = 'tip', data = tips)

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'day', style = 'time', size = 'smoker')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['smoker'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = tips['total_bill'], y = tips['tip'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x = tips['total_bill'], y = tips['tip'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x = tips['total_bill'], y = tips['tip'])
sns.scatterplot(x = tips['total_bill'], y = tips['tip'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x = tips['total_bill'], y = tips['tip'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
fig, ax = plt.subplots(1, 3, figsize = (12, 8))
sns.lineplot(x = tips['total_bill'], y = tips['tip'], ax = ax[0])
sns.scatterplot(x = tips['total_bill'], y = tips['tip'], ax = ax[1])
sns.regplot(x = tips['total_bill'], y = tips['tip'], ax = ax[2])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x = tips['total_bill'], y = tips['tip'], kind = 'scatter', col = tips['day'])

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = tips['total_bill'], y = tips['tip'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize = (12, 8))
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'day', style = 'time', size = 'smoker')
plt.savefig('crazyplot.jpg')

# %% [markdown]
# # Distribution Plots

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### rugplot

# %%
sns.rugplot(x = tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.rugplot(x = 'total_bill', data = tips, height = 0.5)
plt.savefig('rugplot.jpg')

# %% [markdown]
# ### displot & histplot

# %%
sns.displot(x = 'total_bill', data = tips, col = 'day')

# %%
sns.histplot(x = 'total_bill', data = tips, hue = 'day')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x = tips['total_bill'], kde = True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x = tips['total_bill'], kde = True, bins = 20)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
plt.figure(figsize = (12, 8))
sns.set(style = 'whitegrid')
sns.histplot(x = 'total_bill', data= tips, bins = 20, kde = True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ### kdeplot

# %%
sns.kdeplot(x = 'total_bill', data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(x = 'total_bill', data = tips, clip = [5, 30])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize = (12, 8))
sns.kdeplot(x = 'total_bill', y = 'tip', data = tips)
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'day')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Scatterplot

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(figsize = (16, 10))
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'day', style = 'time', size = 'smoker')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
fig, ax = plt.subplots(3, 1, figsize = (12, 8))
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, ax = ax[0])
sns.lineplot(x = 'total_bill', y = 'tip', data = tips, ax = ax[1])
sns.regplot(x = 'total_bill', y = 'tip', data = tips, ax = ax[2])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, kind = 'scatter', col = 'time')

# %% [markdown]
# ### Pandas Built-in  (.plot())

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['total_bill'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.histplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
tips.plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
tips['total_bill'].plot(kind = 'hist', bins = 20, figsize = (12, 8))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tips['total_bill'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
x = np.random.normal(0, 3, 100)
y = np.random.normal(0, 1, 100)
fig, ax = plt.subplots()
ax.scatter(x,y, marker='.')
ax.set_aspect('equal')
ax.set(xlim=(-13,13))
ax.set(ylim=(-8,8))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
sns.kdeplot(x,y, fill=True, shade_lowest=True, alpha=0.7, linewidths=3, \
            cmap='coolwarm', ax=ax, cbar=True, cbar_ax = cax)
colour = ax.collections[1].get_facecolor()
# Out:
# /home/navarra/snap/jupyter/common/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/navarra/snap/jupyter/common/lib/python3.7/site-packages/seaborn/distributions.py:1676: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0`, but please update your code.
#   warnings.warn(msg, UserWarning)
# /home/navarra/snap/jupyter/common/lib/python3.7/site-packages/seaborn/distributions.py:1185: UserWarning: linewidths is ignored by contourf
#   **contour_kws,
