# %% [markdown]
# # SF Salaries Exercise
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# ** Import pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# ** Read Salaries.csv as a dataframe called sal.**

# %%
sal = pd.read_csv('Salaries.csv')

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**

# %%
sal['BasePay'].mean()
# Out:
# 66325.4488404877

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
sal['OvertimePay'].sort_values(ascending = False)[1]
# Out:
# 245131.88

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll). **

# %%
sal['JobTitle'][sal['EmployeeName'] == 'JOSEPH DRISCOLL']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
sal['TotalPayBenefits'][sal['EmployeeName'] == 'JOSEPH DRISCOLL']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ** What is the name of highest paid person (including benefits)?**

# %%
sal.sort_values(by = 'TotalPayBenefits', ascending = False).iloc[[0]]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
sal.loc[[sal['TotalPayBenefits'].idxmax()]]   # idxmax() is similar numpy argmax()
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
sal.iloc[[sal['TotalPayBenefits'].argmax()]]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %% [markdown]
# ** What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
sal.sort_values(by = 'TotalPayBenefits').iloc[[0]]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
sal.loc[[sal['TotalPayBenefits'].idxmin()]]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
sal.iloc[[sal['TotalPayBenefits'].argmin()]]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? **

# %%
sal['Year'].unique()
# Out:
# array([2011, 2012, 2013, 2014])

# %%
sal.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
sal.groupby('Year').mean()['BasePay'][[2011, 2013]]
# Out:
# Year
# 2011    63595.956517
# 2013    69630.030216
# Name: BasePay, dtype: float64

# %% [markdown]
# ** How many unique job titles are there? **

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %%
len(sal['JobTitle'].unique())
# Out:
# 2159

# %% [markdown]
# ** What are the top 5 most common jobs? **

# %%
sal['JobTitle'].value_counts()[:5]
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
type(sal['JobTitle'].value_counts())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?) **

# %%
sal[['JobTitle']][sal['Year'] == 2013].nunique()
# Out:
# JobTitle    1051
# dtype: int64

# %%
sal[['JobTitle']][sal['Year'] == 2013].value_counts() == 1
# Out:
# JobTitle
# Transit Operator                False
# Special Nurse                   False
# Registered Nurse                False
# Public Svc Aide-Public Works    False
# Custodian                       False
#                                 ...
# Board Scty, MTA                  True
# Special Assistant 16             True
# Trnst Power Line Wrk Sprv 2      True
# Special Assistant 15             True
# Real Estate Devt. Mgr, SFMTA     True
# Length: 1051, dtype: bool

# %%
sum(sal[['JobTitle']][sal['Year'] == 2013].value_counts() == 1)
# Out:
# 202

# %% [markdown]
# ** How many people have the word Chief in their job title? (This is pretty tricky) **

# %%
sum(sal['JobTitle'].apply(str.lower).str.contains('chief'))
# Out:
# 627

# %%
sal['JobTitle'][sal['JobTitle'].apply(str.lower).str.contains('chief')].value_counts().index
# Out:
# Index(['Assistant Chief Attorney 1', 'Battalion Chief, Fire Suppress',
#        'Chief Clerk', 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#        'Chief Stationary Engineer', 'Battlion Chief, Fire Suppressi',
#        'ASSISTANT CHIEF ATTORNEY I', 'CHIEF STATIONARY ENGINEER, SEWAGE PLANT',
#        'Deputy Chief 3', 'Chief Surveyor', 'Assistant Chief Attorney 2',
#        'CHIEF CLERK', 'CHIEF STATIONARY ENGINEER',
#        'Chief Atty1 (Civil & Criminal)', 'Chief Building Inspector',
#        'Assistant Deputy Chief 2', 'Chief Deputy Sheriff',
#        'Chief Water Service Inspector', 'CHIEF SURVEYOR',
#        'CHIEF ATTORNEY I (CIVIL & CRIMINAL)', 'ASSISTANT DEPUTY CHIEF II',
#        'ASSISTANT CHIEF ATTORNEY II', 'Chief Preparator',
#        'CHIEF STATIONARY ENGINEER, WATER TREATMENT PLANT',
#        'ASSISTANT CHIEF VICTIM/WITNESS INVESTIGATOR',
#        'DEPUTY CHIEF III (POLICE DEPARTMENT)', 'Chief Dietitian',
#        'ASSISTANT CHIEF DISTRICT ATTORNEY'S INVESTIGATOR',
#        'CHIEF PAYROLL AND PERSONNEL CLERK', 'Chief Deputy Adlt Probation Of',
#        'CHIEF WATER SERVICE INSPECTOR', 'CHIEF DEPUTY SHERIFF',
#        'Chief Electrical Inspector', 'Chief of Police',
#        'Emergency Medical Svcs Chief', 'Chief Telephone Operator',
#        'Chief, Fire Department', 'Chief Nursery Specialist',
#        'CHIEF BUILDING INSPECTOR',
#        'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',
#        'Chief Dep Adlt Prob Of (SFERS)',
#        'CONFIDENTIAL CHIEF ATTORNEY II (CIVIL & CRIMINAL)',
#        'ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#        'Chief Fire Alarm Dispatcher', 'Chief Housing Inspector',
#        'Chief Plumbing Inspector', 'Chief Adult Probation Officer',
#        'CHIEF PREPARATOR', 'CHIEF DEPUTY ADULT PROBATION OFFICER',
#        'CHIEF ADULT PROBATION OFFICER', 'CHIEF DIETITIAN',
#        'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#        'CHIEF VICTIM/WITNESS INVESTIGATOR',
#        'CHIEF DISTRICT ATTORNEY'S INVESTIGATOR',
#        'ASST. CHIEF, BUREAU OF CLAIMS INVEST. & ADMIN',
#        'CHIEF FIRE ALARM DISPATCHER', 'CHIEF TELEPHONE OPERATOR',
#        'CHIEF ELECTRICAL INSPECTOR', 'CHIEF NURSERY SPECIALIST',
#        'CHIEF OF POLICE', 'CHIEF PLUMBING INSPECTOR',
#        'ASST. CHIEF PROBATION OFFICER-JUVENILE PROBATION',
#        'Chief Investment Officer', 'CHIEF MICROBIOLOGIST',
#        'CHIEF PROBATION OFFICER, JUVENILE COURT', 'CHIEF HOUSING INSPECTOR',
#        'Chief Forensic Toxicologist'],
#       dtype='object')

# %% [markdown]
# ** Bonus: Is there a correlation between length of the Job Title string and Salary? **

# %%
title_len = sal['JobTitle'].apply(len)

# %%
import numpy as np

# %%
np.corrcoef(title_len, sal['TotalPayBenefits'])
# Out:
# array([[ 1.        , -0.03687845],
#        [-0.03687845,  1.        ]])

# %%
sal['title_len'] = sal['JobTitle'].apply(len)

# %%
sal[['TotalPayBenefits', 'title_len']].corr('pearson')
# Out:
#                   TotalPayBenefits  title_len
# TotalPayBenefits          1.000000  -0.036878
# title_len                -0.036878   1.000000

# %% [markdown]
# # Great Job!
